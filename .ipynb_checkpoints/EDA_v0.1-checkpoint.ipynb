# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import numpy as np
from path import Path
import pandas_profiling

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
DIR=Path('listing_price_suggest.csv')
DIR
# Out:
# Path('listing_price_suggest.csv')

# %%
df=pd.read_csv(DIR)

# %%
df.head()
# Out:
#    primary_key  y_var  x1var_cat  x2var_cat  x3var_cont  x4var_cont  \
# 0            9     80          1          2        15.9      1.3043
# 1           57      0          0          1        58.3      0.0000
# 2          105      0          3          1       143.1      0.0000
# 3          153     37          3          1       169.6      4.3478
# 4          201      0          0          2       148.4      0.0000
#
#    x5var_cont  x6var_cont  x7var_cont  x8var_cont  x9var_cat  x10var_cont  \
# 0        1.13     15.0787        0.00         0.0          0       0.5479
# 1        0.00      0.0750        0.00         0.0          1       0.6849
# 2        0.00      0.0750        0.00         0.0          0       0.1369
# 3        5.65     27.0817       76.59         0.0          0      44.5205
# 4        0.00      0.0750        0.00         0.0          0       0.0000
#
#    x11var_cont  x12var_cat  x13var_cont  x14var_cont  x15var_cont
# 0       0.0000           0          0.0       1.5300       0.0000
# 1       1.4400           0          0.0       1.5300       0.0533
# 2       0.0000           0          0.0       1.5300       0.0000
# 3      11.1542           0          0.0       0.3642       0.0000
# 4       0.0000           0          0.0       1.5300       0.0000

# %%
df.describe().T
# Out:
#                 count           mean           std      min         25%  \
# primary_key  319487.0  159744.000000  92228.097064    1.000  79872.5000
# y_var        319487.0      57.655423    179.245087    0.000      0.0000
# x1var_cat    319487.0       1.974127      1.361080    0.000      0.0000
# x2var_cat    319487.0       1.025848      0.376719    0.000      1.0000
# x3var_cont   319487.0     120.814493     98.423222 -111.300     42.4000
# x4var_cont   319487.0       3.992371      6.090880    0.000      0.0000
# x5var_cont   319487.0      21.700887     64.094261    0.000      0.0000
# x6var_cont   319487.0      41.378022    180.262947    0.075      0.0750
# x7var_cont   319487.0     338.729146   2240.796016    0.000      0.0000
# x8var_cont   319487.0       0.024758      0.241079    0.000      0.0000
# x9var_cat    319487.0       0.529521      0.499129    0.000      0.0000
# x10var_cont  319487.0     336.203385   1528.175506    0.000      0.1369
# x11var_cont  319487.0      17.278973     29.175233    0.000      0.0000
# x12var_cat   319487.0       0.026414      0.160364    0.000      0.0000
# x13var_cont  319487.0       0.189245      7.497599    0.000      0.0000
# x14var_cont  319487.0       0.846410      0.661773    0.000      0.0962
# x15var_cont  319487.0      82.978004    456.226747    0.000      0.0000
#
#                      50%          75%          max
# primary_key  159744.0000  239615.5000  319487.0000
# y_var            16.0000      57.0000   26209.0000
# x1var_cat         3.0000       3.0000       3.0000
# x2var_cat         1.0000       1.0000       2.0000
# x3var_cont      100.7000     180.2000     482.3000
# x4var_cont        0.4347       6.0869      39.1304
# x5var_cont        1.1300      16.9500    4126.7600
# x6var_cont        2.7006      29.7824   37246.8454
# x7var_cont        6.6600     153.1800  652856.4900
# x8var_cont        0.0000       0.0000      28.0000
# x9var_cat         1.0000       1.0000       1.0000
# x10var_cont      12.8767     182.4657  236710.5479
# x11var_cont       6.1094      21.9334     767.2687
# x12var_cat        0.0000       0.0000       1.0000
# x13var_cont       0.0000       0.0000    2239.4400
# x14var_cont       0.9562       1.5300       1.5300
# x15var_cont       0.0533      45.7267  121276.3133

# %%
df['y_var'].median(),df['y_var'].value_counts().index[1]
# Out:
# (16.0, 20)

# %%
df['y_var'].plot(figsize=(15,8))
plt.plot(df['y_var'].mean(),label='mean -price')
plt.legend()
plt.title("price of various variables-Overview")
plt.show()
# Out:
# Text(0.5,1,'price of various variables-Overview')

# %%
df.iloc[:,1:].plot(figsize=(15,30),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002289930BF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289938B3C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228993B1D30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228993E26D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B45F080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B45F0B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B4B5390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B4DBCC0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B50B668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B533FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B561978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B590320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B5B3C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B5E5630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B60CF98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289B63A940>],
#       dtype=object)

# %%
# same above plot plotted with X axis as primary id
df.plot(figsize=(15,30),subplots=True,x="primary_key")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002289C064320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289C181748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289C1A70F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289C1CCA58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289C1FD400>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289C1FD438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289C250710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EA520B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EA75A20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EAA73C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EACDD30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EAFC6D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EB2B080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EB509E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EB79F28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289EBA88D0>],
#       dtype=object)

# %%
cat_columns=df.columns[df.columns.str.contains("cat")].tolist()
con_columns=df.columns[~df.columns.str.contains("cat")].tolist()
cat_columns,con_columns
# Out:
# (['x1var_cat', 'x2var_cat', 'x9var_cat', 'x12var_cat'],
#  ['primary_key',
#   'y_var',
#   'x3var_cont',
#   'x4var_cont',
#   'x5var_cont',
#   'x6var_cont',
#   'x7var_cont',
#   'x8var_cont',
#   'x10var_cont',
#   'x11var_cont',
#   'x13var_cont',
#   'x14var_cont',
#   'x15var_cont'])

# %%
df[con_columns].iloc[1:].plot(subplots=True,figsize=(15,30))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002289F473F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F509668>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F51EFD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F54D978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F57C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F57C358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F5D35F8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F5F8F60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F628908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F6582B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F67DC18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F6AE5C0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002289F6D3F28>],
#       dtype=object)

# %% [markdown]
# ## visualizing Distribuitions

# %%
df['y_var'].plot(kind='hist',bins=50)

# %%
df[con_columns].iloc[:,1:].plot(subplots=True,figsize=(15,30),kind='hist',bins=100)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D72274EF28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D7227A1240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722A41B38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722A714E0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722A95E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722A95E80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722DA4198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722DC9B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722DFA4A8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722E1FE10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722E4D7B8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D722E7C160>],
#       dtype=object)

# %%
for i in cat_columns:
    df[i].value_counts().plot(kind='bar')
    plt.title(i)
    plt.show()

# %%
from IPython.display import IFrame

IFrame(src='./listing_price_suggest_profile.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="./listing_price_suggest_profile.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Missing Value Treatment -No missing value found

# %%
df.isnull().sum()
# Out:
# primary_key    0
# y_var          0
# x1var_cat      0
# x2var_cat      0
# x3var_cont     0
# x4var_cont     0
# x5var_cont     0
# x6var_cont     0
# x7var_cont     0
# x8var_cont     0
# x9var_cat      0
# x10var_cont    0
# x11var_cont    0
# x12var_cat     0
# x13var_cont    0
# x14var_cont    0
# x15var_cont    0
# dtype: int64

# %% [markdown]
# ### common y_var analysis

# %%
df['y_var'].value_counts()
# Out:
# 0        124555
# 20         7695
# 15         7092
# 10         6469
# 25         6435
# 30         5892
# 40         4827
# 35         4345
# 50         4136
# 12         3634
# 18         3441
# 45         3422
# 8          3126
# 60         2761
# 13         2481
# 55         2371
# 22         2268
# 65         2216
# 28         2129
# 16         1963
# 75         1952
# 14         1887
# 70         1856
# 9          1814
# 5          1796
# 38         1699
# 32         1652
# 80         1638
# 17         1632
# 7          1607
#           ...
# 1402          1
# 3963          1
# 1147          1
# 1403          1
# 3975          1
# 2439          1
# 3716          1
# 1413          1
# 1668          1
# 1156          1
# 2181          1
# 1411          1
# 2434          1
# 1410          1
# 1154          1
# 18313         1
# 1665          1
# 11652         1
# 2176          1
# 1920          1
# 2945          1
# 4738          1
# 1919          1
# 2430          1
# 1918          1
# 2431          1
# 2941          1
# 6527          1
# 1915          1
# 1658          1
# Name: y_var, Length: 1834, dtype: int64

# %% [markdown]
# ## Ask Questions:
#      - This Session is completely dedicated to ask various Questions about the Dataset
#         This helps us to better understand the data and find insights
#
# Question 1:
#  - Target variable `y_var` most common value is Zero Why ?
#    - Since most of the time we are getting Zero as our recommended price,Lets Analayse why we are getting zero
#
# - Analyse the categories of the categorical column and try to find insights?
#
# - Why `primary_key` is different and it is producing some pattern `(Seasonality and Trend)`  while plotting ?
#     - Assumptions :
#         - This may be due to the Sampling the data
#         - Data may arrive at this particular order (if this is case we can identify
#         the Data Arrival pattern and try to build feature around it)

# %%
zero_price_df=df[df['y_var']==0]
zero_price_df.plot(subplots=True,figsize=(15,30))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000228B11521D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B11788D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B11A1E80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B11D1470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B11F8B38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B11F8B70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B124FE48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B127D7F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B12AC198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B12D0AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B1301470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B1323DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B1354780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B1384128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B13A8A90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B13D7438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000228B13FEDA0>],
#       dtype=object)

# %%
zero_price_df.describe().T
df.describe().T
zero_price_df.describe().T-df.describe().T
# Out:
#                 count           mean           std    min        25%  \
# primary_key  124555.0  159721.466404  92205.766000  3.000  79722.500
# y_var        124555.0       0.000000      0.000000  0.000      0.000
# x1var_cat    124555.0       1.659781      1.447473  0.000      0.000
# x2var_cat    124555.0       1.054321      0.441283  0.000      1.000
# x3var_cont   124555.0     121.266579     94.470866  0.000     42.400
# x4var_cont   124555.0       0.993618      3.595175  0.000      0.000
# x5var_cont   124555.0       0.896588      7.635046  0.000      0.000
# x6var_cont   124555.0       1.975508     17.769777  0.075      0.075
# x7var_cont   124555.0      18.992376   1872.950264  0.000      0.000
# x8var_cont   124555.0       0.000064      0.011334  0.000      0.000
# x9var_cat    124555.0       0.082959      0.275822  0.000      0.000
# x10var_cont  124555.0      12.587222    164.361364  0.000      0.000
# x11var_cont  124555.0       2.403963      6.434966  0.000      0.000
# x12var_cat   124555.0       0.001509      0.038821  0.000      0.000
# x13var_cont  124555.0       0.003922      0.266553  0.000      0.000
# x14var_cont  124555.0       1.421664      0.306667  0.000      1.530
# x15var_cont  124555.0       2.760280     60.741971  0.000      0.000
#
#                     50%          75%          max
# primary_key  159570.000  239539.5000  319484.0000
# y_var             0.000       0.0000       0.0000
# x1var_cat         3.000       3.0000       3.0000
# x2var_cat         1.000       1.0000       2.0000
# x3var_cont      100.700     180.2000     482.3000
# x4var_cont        0.000       0.0000      37.3913
# x5var_cont        0.000       0.0000     552.5700
# x6var_cont        0.075       0.0750    1502.2018
# x7var_cont        0.000       0.0000  652856.4900
# x8var_cont        0.000       0.0000       3.0000
# x9var_cat         0.000       0.0000       1.0000
# x10var_cont       0.000       0.9589   15690.9589
# x11var_cont       0.000       2.8800     318.7446
# x12var_cat        0.000       0.0000       1.0000
# x13var_cont       0.000       0.0000      55.0400
# x14var_cont       1.530       1.5300       1.5300
# x15var_cont       0.000       0.0000    7499.0933
#                 count           mean           std      min         25%  \
# primary_key  319487.0  159744.000000  92228.097064    1.000  79872.5000
# y_var        319487.0      57.655423    179.245087    0.000      0.0000
# x1var_cat    319487.0       1.974127      1.361080    0.000      0.0000
# x2var_cat    319487.0       1.025848      0.376719    0.000      1.0000
# x3var_cont   319487.0     120.814493     98.423222 -111.300     42.4000
# x4var_cont   319487.0       3.992371      6.090880    0.000      0.0000
# x5var_cont   319487.0      21.700887     64.094261    0.000      0.0000
# x6var_cont   319487.0      41.378022    180.262947    0.075      0.0750
# x7var_cont   319487.0     338.729146   2240.796016    0.000      0.0000
# x8var_cont   319487.0       0.024758      0.241079    0.000      0.0000
# x9var_cat    319487.0       0.529521      0.499129    0.000      0.0000
# x10var_cont  319487.0     336.203385   1528.175506    0.000      0.1369
# x11var_cont  319487.0      17.278973     29.175233    0.000      0.0000
# x12var_cat   319487.0       0.026414      0.160364    0.000      0.0000
# x13var_cont  319487.0       0.189245      7.497599    0.000      0.0000
# x14var_cont  319487.0       0.846410      0.661773    0.000      0.0962
# x15var_cont  319487.0      82.978004    456.226747    0.000      0.0000
#
#                      50%          75%          max
# primary_key  159744.0000  239615.5000  319487.0000
# y_var            16.0000      57.0000   26209.0000
# x1var_cat         3.0000       3.0000       3.0000
# x2var_cat         1.0000       1.0000       2.0000
# x3var_cont      100.7000     180.2000     482.3000
# x4var_cont        0.4347       6.0869      39.1304
# x5var_cont        1.1300      16.9500    4126.7600
# x6var_cont        2.7006      29.7824   37246.8454
# x7var_cont        6.6600     153.1800  652856.4900
# x8var_cont        0.0000       0.0000      28.0000
# x9var_cat         1.0000       1.0000       1.0000
# x10var_cont      12.8767     182.4657  236710.5479
# x11var_cont       6.1094      21.9334     767.2687
# x12var_cat        0.0000       0.0000       1.0000
# x13var_cont       0.0000       0.0000    2239.4400
# x14var_cont       0.9562       1.5300       1.5300
# x15var_cont       0.0533      45.7267  121276.3133
#                 count        mean          std    min       25%       50%  \
# primary_key -194932.0  -22.533596   -22.331063    2.0 -150.0000 -174.0000
# y_var       -194932.0  -57.655423  -179.245087    0.0    0.0000  -16.0000
# x1var_cat   -194932.0   -0.314346     0.086393    0.0    0.0000    0.0000
# x2var_cat   -194932.0    0.028474     0.064564    0.0    0.0000    0.0000
# x3var_cont  -194932.0    0.452086    -3.952357  111.3    0.0000    0.0000
# x4var_cont  -194932.0   -2.998753    -2.495704    0.0    0.0000   -0.4347
# x5var_cont  -194932.0  -20.804299   -56.459215    0.0    0.0000   -1.1300
# x6var_cont  -194932.0  -39.402515  -162.493170    0.0    0.0000   -2.6256
# x7var_cont  -194932.0 -319.736771  -367.845752    0.0    0.0000   -6.6600
# x8var_cont  -194932.0   -0.024694    -0.229745    0.0    0.0000    0.0000
# x9var_cat   -194932.0   -0.446561    -0.223307    0.0    0.0000   -1.0000
# x10var_cont -194932.0 -323.616163 -1363.814142    0.0   -0.1369  -12.8767
# x11var_cont -194932.0  -14.875009   -22.740267    0.0    0.0000   -6.1094
# x12var_cat  -194932.0   -0.024905    -0.121542    0.0    0.0000    0.0000
# x13var_cont -194932.0   -0.185324    -7.231046    0.0    0.0000    0.0000
# x14var_cont -194932.0    0.575253    -0.355105    0.0    1.4338    0.5738
# x15var_cont -194932.0  -80.217724  -395.484776    0.0    0.0000   -0.0533
#
#                   75%          max
# primary_key  -76.0000      -3.0000
# y_var        -57.0000  -26209.0000
# x1var_cat      0.0000       0.0000
# x2var_cat      0.0000       0.0000
# x3var_cont     0.0000       0.0000
# x4var_cont    -6.0869      -1.7391
# x5var_cont   -16.9500   -3574.1900
# x6var_cont   -29.7074  -35744.6436
# x7var_cont  -153.1800       0.0000
# x8var_cont     0.0000     -25.0000
# x9var_cat     -1.0000       0.0000
# x10var_cont -181.5068 -221019.5890
# x11var_cont  -19.0534    -448.5241
# x12var_cat     0.0000       0.0000
# x13var_cont    0.0000   -2184.4000
# x14var_cont    0.0000       0.0000
# x15var_cont  -45.7267 -113777.2200

# %%
import seaborn as sns

sns.heatmap(zero_price_df.describe().T)
plt.show()
sns.heatmap(df.describe().T)
plt.show()
sns.heatmap(zero_price_df.describe().T-df.describe().T)

# %% [markdown]
# ### Correlation insights

# %%
fig=plt.subplots(figsize=(15,15))
corr=df.iloc[:,1:].corr()
sns.heatmap(corr)

# %%
corr['y_var'].plot(kind='bar')
plt.title("Correlation between predictor and target variable")
plt.show()
# Out:
# Text(0.5,1,'Correlation between predictor and target variable')
